# %% [markdown]
# ### vector reading

# %%
import geopandas
import matplotlib.pyplot as plt

# %%
path_data = 'data/data-base/ChinaAdminDivisonSHP/4. District/district.shp'
path_out = 'data/data-section-3/kunming_district_gpd.gpkg'

# %%
gpd = geopandas.read_file(path_data)

# %% [markdown]
# 信息查看

# %%
gpd.head()
# Out:
#   dt_adcode dt_name ct_adcode ct_name pr_adcode pr_name cn_adcode  cn_name  \
# 0    110101     东城区    110100    北京城区    110000     北京市    100000  中华人民共和国
# 1    110102     西城区    110100    北京城区    110000     北京市    100000  中华人民共和国
# 2    110105     朝阳区    110100    北京城区    110000     北京市    100000  中华人民共和国
# 3    110106     丰台区    110100    北京城区    110000     北京市    100000  中华人民共和国
# 4    110107    石景山区    110100    北京城区    110000     北京市    100000  中华人民共和国
#
#                                             geometry
# 0  POLYGON ((116.38766 39.96092, 116.38948 39.961...
# 1  POLYGON ((116.39301 39.96916, 116.39235 39.968...
# 2  MULTIPOLYGON (((116.44393 39.87442, 116.44412 ...
# 3  POLYGON ((116.16577 39.77444, 116.16516 39.773...
# 4  POLYGON ((116.15157 39.99344, 116.15341 39.992...

# %%
### 简单可视化
# gpd.plot() 
gpd.plot(column='dt_name', figsize=(5,6), edgecolor='black')
# Out:
# <Axes: >

# %%
## 投影信息
gpd.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# print(gpd.bounds)
print(gpd.total_bounds)
# Out:
# [ 73.502355   3.83703  135.09567   53.563624]

# %% [markdown]
# 选取数据

# %%
kunming_gpd = gpd[gpd['ct_name'] == '昆明市']
# kunming_gpd = gpd.iloc[gpd['ct_name'].values == '昆明市']
kunming_gpd.head()
# Out:
#      dt_adcode dt_name ct_adcode ct_name pr_adcode pr_name cn_adcode  cn_name  \
# 2279    530102     五华区    530100     昆明市    530000     云南省    100000  中华人民共和国
# 2280    530103     盘龙区    530100     昆明市    530000     云南省    100000  中华人民共和国
# 2281    530111     官渡区    530100     昆明市    530000     云南省    100000  中华人民共和国
# 2282    530112     西山区    530100     昆明市    530000     云南省    100000  中华人民共和国
# 2283    530113     东川区    530100     昆明市    530000     云南省    100000  中华人民共和国
#
#                                                geometry
# 2279  MULTIPOLYGON (((102.71331 25.13652, 102.71547 ...
# 2280  POLYGON ((102.71668 25.04473, 102.71663 25.045...
# 2281  POLYGON ((102.71717 25.03341, 102.71792 25.033...
# 2282  MULTIPOLYGON (((102.50726 24.86019, 102.50689 ...
# 2283  POLYGON ((102.8034 26.30291, 102.80537 26.3031...

# %% [markdown]
# 矢量数据写出

# %%
kunming_gpd.to_file(path_out)
# kunming_gpd.to_file(path_out, driver='GPKG')
